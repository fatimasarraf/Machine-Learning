# %% [markdown]
# Tp3ex1

# %%
# Importation de librairies
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Acquisition des données
df = pd.read_csv("Classified Data.csv", index_col=0)
print(df.head())

# La normalisation des features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df.drop('TARGET CLASS', axis=1))
scaled_features = scaler.transform(df.drop('TARGET CLASS', axis=1))
df_feat = pd.DataFrame(scaled_features, columns=df.columns[:-1])
print(df_feat.head())

# Séparation des données d’apprentissage et données de test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_features, df['TARGET CLASS'], test_size=0.30)

# Utilisation des KPPV
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# Plus de détails concernant le classifieur KNN
help(KNeighborsClassifier)
# Prédictions et évaluations
from sklearn.metrics import classification_report, confusion_matrix

print("Matrice de confusion :")
print(confusion_matrix(y_test, pred))

print("\nRapport de classification :")
print(classification_report(y_test, pred))
# Choisir une valeur de K
error_rate = []

# Il est recommandé de vérifier les performances pour toutes les valeurs de K entre 1 et 40
for i in range(1, 41):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10, 6))
plt.plot(range(1, 41), error_rate, color='blue', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title("Taux d'erreur en fonction de la valeur de K")
plt.xlabel('K')
plt.ylabel("Taux d'erreur")
plt.show()

# Ré-entraîner le modèle avec la valeur de K choisie
# Utilisons d'abord K=1 pour la comparaison
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
print("AVEC K=1")
print()
print(confusion_matrix(y_test, pred))
print()
print(classification_report(y_test, pred))

# Maintenant, utilisons K=23 comme valeur choisie
knn = KNeighborsClassifier(n_neighbors=23)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
print("AVEC K=23")
print()
print(confusion_matrix(y_test, pred))
print()
print(classification_report(y_test, pred))
# Out:
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608  0.759697
# 1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450  0.675334
# 2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781  1.626351
# 3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128  1.409708
# 4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727  1.115596
#
#         PJF       HQE       NXJ  TARGET CLASS
# 0  0.643798  0.879422  1.231409             1
# 1  1.013546  0.621552  1.492702             0
# 2  1.154483  0.957877  1.285597             0
# 3  1.380003  1.522692  1.153093             1
# 4  0.646691  1.463812  1.419167             1
#         WTT       PTI       EQW       SBI       LQE       QWG       FDJ  \
# 0 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375 -0.798951
# 1 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706 -1.129797
# ...

# %% [markdown]
# Tp3Ex2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report

# Chargement des données
df = pd.read_csv("Classified Data.csv", index_col=0)

# Normalisation des fonctionnalités
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df.drop('TARGET CLASS', axis=1))
df_feat = pd.DataFrame(scaled_features, columns=df.columns[:-1])

# Division des données en ensembles d'apprentissage et de test
X_train, X_test, y_train, y_test = train_test_split(scaled_features, df['TARGET CLASS'], test_size=0.30)

# Liste des différentes métriques de distance à tester
distance_metrics = ['euclidean', 'manhattan', 'chebyshev', 'minkowski']

# Dictionnaire pour stocker les résultats pour chaque métrique
results = {}

# Loop sur chaque métrique de distance
for metric in distance_metrics:
    # Stockage des résultats pour chaque valeur de K
    metric_results = {}
    for k in range(1, 41):  # Tester les valeurs de K de 1 à 40
        knn = KNeighborsClassifier(n_neighbors=k, metric=metric)
        knn.fit(X_train, y_train)
        pred = knn.predict(X_test)
        metric_results[k] = {'confusion_matrix': confusion_matrix(y_test, pred),
                             'classification_report': classification_report(y_test, pred)}
    results[metric] = metric_results

# Comparaison des résultats obtenus pour chaque métrique de distance
for metric, metric_results in results.items():
    print(f"Résultats avec la métrique de distance {metric}:")
    best_k = min(metric_results, key=lambda x: np.mean(metric_results[x]['confusion_matrix']))
    print(f"Meilleure valeur de K: {best_k}")
    print(f"Matrice de confusion pour la meilleure valeur de K:")
    print(metric_results[best_k]['confusion_matrix'])
    print(f"Rapport de classification pour la meilleure valeur de K:")
    print(metric_results[best_k]['classification_report'])
    print()
# Out:
# Résultats avec la métrique de distance euclidean:
# Meilleure valeur de K: 1
# Matrice de confusion pour la meilleure valeur de K:
# [[128  21]
#  [ 10 141]]
# Rapport de classification pour la meilleure valeur de K:
#               precision    recall  f1-score   support
#
#            0       0.93      0.86      0.89       149
#            1       0.87      0.93      0.90       151
#
#     accuracy                           0.90       300
#    macro avg       0.90      0.90      0.90       300
# weighted avg       0.90      0.90      0.90       300
#
#
# Résultats avec la métrique de distance manhattan:
# Meilleure valeur de K: 1
# Matrice de confusion pour la meilleure valeur de K:
# [[128  21]
#  [ 13 138]]
# Rapport de classification pour la meilleure valeur de K:
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88       149
#            1       0.87      0.91      0.89       151
#
# ...

# %% [markdown]
# partie2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Chargement des données
df = pd.read_csv("iris.csv")

# Division des données en caractéristiques (X) et étiquettes (y)
X = df.drop('species', axis=1)
y = df['species']

# Division des données en ensembles d'apprentissage et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Création et entraînement du modèle KPPV
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)

# Prédictions sur les données de test
predictions = knn.predict(X_test)

# Évaluation des performances du modèle
print("Matrice de confusion :")
print(confusion_matrix(y_test, predictions))
print("\nRapport de classification :")
print(classification_report(y_test, predictions))
# Out:
# Matrice de confusion :
# [[18  0  0]
#  [ 0 16  0]
#  [ 0  0 11]]
#
# Rapport de classification :
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        18
# Iris-versicolor       1.00      1.00      1.00        16
#  Iris-virginica       1.00      1.00      1.00        11
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# parti3

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# Chargement des données
df = pd.read_csv("Salary_Data (1).csv")

# Division des données en caractéristiques (X) et variable cible (y)
X = df.drop('Salary', axis=1)
y = df['Salary']

# Division des données en ensembles d'apprentissage et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Création et entraînement du modèle KPPV pour la régression
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)

# Prédictions sur les données de test
predictions = knn.predict(X_test)

# Évaluation des performances du modèle
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error (MSE) :", mse)
# Out:
# Mean Squared Error (MSE) : 41499416.60444446
